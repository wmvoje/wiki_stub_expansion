# %%
import sys

# %%
import unicodedata

# %%
sys.path.append('../scripts/')

# %%
import wikipedia_scripts_lxml

# %%
list_of_pages = ['Vagina',
                '3M',
                'XHamster',
                'World_War_I',
                'American Civil War',
                'India',
                'Yemen' ,
                'Lady Gaga',
                'Donald Trump',
                'David Bowie',
                'Martin Luther King Jr.',
                'Google',
                'Reddit',
                'Human penis size',
                'Machine learning',
                'DNA_sequencing',
                'FIFA World Cup',
                'Cricket World Cup']

for page in list_of_pages:
    wikipedia_scripts_lxml.collect_consoidate_historical_edits('../data/test9/', page)
# Out:
# request_started
# request_complete
# ['Vagina', '816130594', '816037476', 'Samuelpla7z', None, '2017-12-19T13:43:01Z', "[[WP:AES|â†\x90]]Replaced content with 'VAGINA TASTES AMAZING EAT IT A LOT'", 34, 7, 0, 0, 0, 0]
# request_started
# request_complete
# request_started
# request_complete
# text indexing error
# <html><head></head><body><id>728449460</id>
#       <parentid>727297325</parentid>
#       <timestamp>2016-07-05T14:37:08Z</timestamp>
#       <contributor>
#         <username>Ø­Ø§Ù…Ø¯ Ø¯Ø§ÙˆØ¯Ù¾ÙˆØ±</username>
#         <id>26801907</id>
#       </contributor>
#       <comment>[[WP:AES|â†]]Blanked the page</comment>
#       <model>wikitext</model>
#       <format>text/x-wiki</format>
#       <text bytes="0" xml:space="preserve"></text>
#       <sha1>phoiac9h4m842xq45sp7s6u21eteeq1</sha1>
#     </body></html>
# request_started
# request_complete
# ...

# %%
import pandas as pd

# %%
pd.read_csv('../data/test/revisions/The_Faint.csv')
# Out:
#    page_title      revid   parentid                user  userid  \
# 0   The_Faint  718693440  668404790          MuzikJunky     NaN
# 1   The_Faint  727284303  718693440     Generic hipster     NaN
# 2   The_Faint  727284587  727284303     Generic hipster     NaN
# 3   The_Faint  727296015  727284587           AnomieBOT     NaN
# 4   The_Faint  727325291  727296015         Cyberbot II     NaN
# 5   The_Faint  732706899  727325291        Synthwave.94     NaN
# 6   The_Faint  733085296  732706899            Malmsimp     NaN
# 7   The_Faint  734806236  733085296                 NaN     NaN
# 8   The_Faint  734812895  734806236             Etron81     NaN
# 9   The_Faint  734812968  734812895             Etron81     NaN
# 10  The_Faint  735170628  734812968                 NaN     NaN
# 11  The_Faint  737016401  735170628          GreenC bot     NaN
# 12  The_Faint  740389923  737016401            Frietjes     NaN
# 13  The_Faint  748497971  744664283  InternetArchiveBot     NaN
# ...

# %%
import pickle

# %%
with open('test.p', 'w') as topick:
    pickle.dump(temp_dict, topick, protocol=0)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-15-d4fc4a76b763> in <module>()
#       1 with open('test.p', 'w') as topick:
# ----> 2     pickle.dump(temp_dict, topick, protocol=0)
#
# c:\users\willi\appdata\local\programs\python\python36-32\lib\copyreg.py in _reduce_ex(self, proto)
#      67     args = (self.__class__, base, state)
#      68     try:
# ---> 69         getstate = self.__getstate__
#      70     except AttributeError:
#      71         if getattr(self, "__slots__", None):
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
import json

# %%
with open('data.json', 'w') as fp:
    json.dump(temp_dict, fp)

# %%
import requests
from bs4 import BeautifulSoup
import dateutil

# %%
earliest_date = '2015-07-01T11:03:28Z'
wiki_title = 'The_Faint'

# %%
url = 'https://en.wikipedia.org/w/index.php?title=Special:Export'
data = {'pages': wiki_title,
        'limit': '1000',
        'offset': str(earliest_date)}

r = requests.post(url=url,
                  data=data)

# %%
r = requests.post(url=url,
                  data=data)

# %%
soup = BeautifulSoup(r.content, 'html5lib')

# %%
soup('revision')[1]
# Out:
# <revision>
#       <id>727284303</id>
#       <parentid>718693440</parentid>
#       <timestamp>2016-06-27T23:25:22Z</timestamp>
#       <contributor>
#         <username>Generic hipster</username>
#         <id>25748668</id>
#       </contributor>
#       <comment>dead links</comment>
#       <model>wikitext</model>
#       <format>text/x-wiki</format>
#       <text bytes="8755" xml:space="preserve">{{Infobox musical artist
# | name             = The Faint
# | image            = TheFaintLive2008-01.jpg
# | caption          = The Faint live on tour 2008
# | background       = group_or_band
# | origin           = [[Omaha, Nebraska]]
# | genre            = [[Indie rock]], [[post-punk revival]], [[dance-punk]], [[New wave music|new wave]]
# | years_active     = 1995&amp;ndash;present
# | label            = Blank.wav, [[Saddle Creek]], [[Astralwerks]]
# | associated_acts  = [[Vverevvolf Grehv]], [[Broken Spindles]], Depressed Buttons, [[Digital Leather]], TIT
# ...

# %%
earliest_date = dateutil.parser.DEFAULTPARSER.parse('2015-07-19T1:1:57Z')

# %%
earliest_date.
# Out:
# '2015-07-19 01:01:57+00:00'
