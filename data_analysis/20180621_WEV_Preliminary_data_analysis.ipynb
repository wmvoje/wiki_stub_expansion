# %%
import os 
import sys
import pandas as pd
import seaborn 
import pathlib

# %matplotlib inline

# %%
# First consolidating all revision data

path_to_revision_data = pathlib.Path('../data/revision_histories/')

for directory in os.listdir(path_to_revision_data):
    
    name_of_page = directory[9:]
    
    path_to_summary = path_to_revision_data / directory / ('summary_' + name_of_page + '.csv')
    
    test = pd.read_csv(path_to_summary)
    
    test.loc[:,'page'] = name_of_page

# %%
test
# Out:
#       Unnamed: 0  Unnamed: 0.1  character_count  \
# 0              0             0           102978
# 1              1             1           102980
# 2              2             2           102980
# 3              3             3           102970
# 4              4             4           102690
# 5              5             5           102690
# 6              6             6           102690
# 7              7             7           102690
# 8              8             8           102690
# 9              9             9           102690
# 10            10            10           102690
# 11            11            11           102748
# 12            12            12           102690
# 13            13            13           102721
# 14            14            14           102690
# 15            15            15           102690
# 16            16            16           102852
# 17            17            17           102852
# ...

# %%
test
# Out:
# WindowsPath('../data/revision_histories/20180619_Martin Luther King Jr')

# %%
test = test / ('summary_' + name_of_page + '.csv')

# %%
thing = pathlib.Path('../data/revision_histories/20180619_3M/summary_3M.csv')

# %%
path = pathlib.Path('../')

# %%
path / 'data' / 'revision_histories' / directory +   == pathlib.Path('../data/revision_histories/20180619_3M/')
# Out:
# True

# %%
directory.
# Out:
# '20180619_3M'

# %%
test.name == thing.name
# Out:
# False

# %%
test.is_file()
# Out:
# False

# %%
thing.is_file()
# Out:
# True

# %%
str(path_to_summary)
# Out:
# '../data/revision_histories/20180619_3M/summary_3M.cvs'

# %%
str(path_to_summary) == '../data/revision_histories/20180619_3M/summary_3M.csv'
# Out:
# False

# %%
path_to_summary
# Out:
# '../data/revision_histories/20180619_3M/summary_3M.cvs'

# %%
'../data/revision_histories/20180619_3M/summary_3M.csv'
# Out:
# '../data/revision_histories/20180619_3M/summary_3M.csv'

# %%
os.path.join(path_to_revision_data, directory +'/', 'summary_3M.cvs')
# Out:
# '../data/revision_histories/20180619_3M/summary_3M.cvs'

# %%
'summary_' + name_of_page + '.cvs'
# Out:
# 'summary_3M.cvs'

# %%
'../data/revision_histories/20180619_3M/summary_3M.csv'

# %%
pd.read_csv('../data/revision_histories/20180619_3M/summary_3M.csv')
# Out:
#       Unnamed: 0  Unnamed: 0.1  character_count  \
# 0              0             0            18931
# 1              1             1            18931
# 2              2             2            18932
# 3              3             3            18932
# 4              4             4            18932
# 5              5             5            18932
# 6              6             6            19054
# 7              7             7            18974
# 8              8             8            18974
# 9              9             9            18974
# 10            10            10            18361
# 11            11            11            18357
# 12            12            12            18361
# 13            13            13            18361
# 14            14            14            18361
# 15            15            15            18361
# 16            16            16            18332
# 17            17            17            18332
# ...

# %%
pd.read_csv(path_to_summary)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-7638e5f00400> in <module>()
# ----> 1 pd.read_csv(path_to_summary)
#
# c:\users\willi\appdata\local\programs\python\python36-32\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...
